# %%
# Day 37 – Introduction to Programming Languages and Python
# Project Title: Student Profile Creator

# 1. Create variables to store student details

student_name = "Rehana"
student_age = 15
favourite_subjects = ["Maths", "Science", "English"]

# 2. Display student’s information in a user-friendly format

print("Student Information System")
print("Name:", student_name)
print("Age:", student_age)
print("Favourite Subjects:", favourite_subjects)


# 3. Update the list of subjects

favourite_subjects.append("History")

print("\n Updated List of Subjects:", favourite_subjects)                         # \n is called a newline character in Python
# Out:
# Student Information System
# Name: Rehana
# Age: 15
# Favourite Subjects: ['Maths', 'Science', 'English']
#
#  Updated List of Subjects: ['Maths', 'Science', 'English', 'History']
